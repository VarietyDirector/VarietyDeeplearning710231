# %% [markdown]
# ### Batch_Crop
# * 한림대학교 딥러닝이해및응용(7210231) 과목 자료입니다
# * Hallym Univ.
# * Deeplearning
# * 2018/11/20

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from dd_nnutil_hallym_batchcrop import *

# %%
folder1 = './data/'

# %%
batch_crop(folder1, to_rotate  = False, resize_ratio = 0.2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-3746a4298d43> in <module>()
# ----> 1 batch_crop(folder1, to_rotate  = False, resize_ratio = 0.2)
#
# ~\712031\dd_nnutil_hallym_batchcrop.py in batch_crop(dirpath, ftypes, resize_ratio, to_rotate, w, h)
#      15
#      16 def batch_crop(dirpath, ftypes = ('jpg', 'JPG'), resize_ratio = 1, to_rotate= False, w = 224, h = 224):
# ---> 17     for folder in os.listdir(dirpath):
#      18         print(folder)
#      19         sav_dir = os.path.join(dirpath, folder +'_crop')
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: './clock1'

# %%
idx = 12
image_class = 10
for i in range( 0, 100, 5):
    fig, ax = plt.subplots(figsize=(20, 10), dpi=80)
    img, img_crop = load_image_compare(folder1, image_class, idx =i)
    plt.subplot(1,2,1)
    plt.imshow(img)
    plt.subplot(1,2,2)
    plt.imshow(img_crop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3ea99a7d32c1> in <module>()
#       1 plt.subplot(1,2,1)
# ----> 2 plt.imshow(img)
#       3 plt.subplot(1,2,2)
#       4 plt.imshow(img_crop)
#
# NameError: name 'img' is not defined

# %%
idx = 12
image_class = 10
fig, ax = plt.subplots(dpi=80)
img, img_crop = load_image_compare(folder1, image_class, idx =idx)
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(img_crop)
